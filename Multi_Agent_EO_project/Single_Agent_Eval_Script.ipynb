# %%
#Single Agent environment 

from Single_ag_Environment import SingleSatelliteEnv
from gymnasium.utils.env_checker import check_env
import traceback
print(type(SingleSatelliteEnv))
# This will catch many common issues
env = SingleSatelliteEnv()
try:
    check_env(env)
    print("Environment passes all checks!")
except Exception as e:
    print("Environment has issues:")
    traceback.print_exc()


#Setup Stable Baseline3 Agents



#Setup CleanRL Agents
# Out:
# <class 'type'>
# Environment has issues:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 9
#       8 try:
# ----> 9     check_env(env)
#      10     print("Environment passes all checks!")
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/utils/env_checker.py:411, in check_env(env, warn, skip_render_check, skip_close_check)
#     410 check_reset_return_info_deprecation(env)
# --> 411 check_reset_return_type(env)
#     412 check_reset_seed_determinism(env)
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/utils/env_checker.py:300, in check_reset_return_type(env)
#     298 obs, info = result
#     299 assert (
# --> 300     obs in env.observation_space
#     301 ), "The first element returned by `env.reset()` is not within the observation space."
#     302 assert isinstance(
#     303     info, dict
#     304 ), f"The second element returned by `env.reset()` was not a dictionary, actual type: {type(info)}"
#
# AssertionError: The first element returned by `env.reset()` is not within the observation space.
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      11 except Exception as e:
#      12     print("Environment has issues:")
# ---> 13     traceback.print_exc()
#      16 #Setup Stable Baseline3 Agents
#      17
#      18
#      19
#      20 #Setup CleanRL Agents
#
# NameError: name 'traceback' is not defined
